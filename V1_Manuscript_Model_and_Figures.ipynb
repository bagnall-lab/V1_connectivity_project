# %% [markdown]
# # Running the V1 Model and Making the Figures in the Manuscript

# %% [markdown]
# #### Spinal V1 neurons inhibit motor targets locally and sensory targets distally to coordinate locomotion
# Mohini Sengupta, Vamsi Daliparthi, Yann Roussel, Tuan Vu Bui, Martha W. Bagnall
# bioRxiv 2021.01.22.427836; doi: https://doi.org/10.1101/2021.01.22.427836

# %%
## Run simulation: 
## Local vs Distal connectivity can be replicated by changing lines 322 and 343 in 
## Beat_and_glide_Ipsilateral_Only_Final.py to Local (0.2 < X < 5.0) and Distal (5.0 < X < 10.0)

# Navigate to where this file is saved on your computer first. 
# %run BeatnGliderunscript_Ipsilateral_Final.py
# Out:
#   0% |                                                                        |
# 15.206048976296614
# 10.5
# 13.951536110028602
# 10.500000000000002
# 100% |########################################################################|
# CIA MN Weights: 10.500000000000002
# CIA CiD Weights: 10.5

# %%
#%cd '~/V1_Manuscript_DATA/Local_CiD_Local_MN_Data'
# %run All_Local_Figure_Script_Final.py
# Out:
# /Users/vamsidaliparthi/Desktop/V1_Manuscript_DATA/Local_CiD_Local_MN_Data

# %%
#%cd '~/V1_Manuscript_DATA/Local_CiD_Distal_MN_Data'
# %run Local_CiD_Distal_MN_Figure_Script.py
# Out:
# /Users/vamsidaliparthi/Desktop/V1_Manuscript_DATA/Local_CiD_Distal_MN_Data

# %%
#%cd '~/V1_Manuscript_DATA/Distal_CiD_Local_MN_Data'
# %run Distal_CiD_Local_MN_Figure_Script.py
# Out:
# /Users/vamsidaliparthi/Desktop/V1_Manuscript_DATA/Distal_CiD_Local_MN_Data

# %%
#%cd '~/V1_Manuscript_DATA/Distal_CiD_Distal_MN_Data'
# %run All_Distal_Figure_Script.py
# Out:
# /Users/vamsidaliparthi/Desktop/V1_Manuscript_DATA/Distal_CiD_Distal_MN_Data
